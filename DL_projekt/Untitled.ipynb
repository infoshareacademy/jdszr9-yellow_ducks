# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import cv2
import matplotlib.pyplot as plt

# %%
datagen = ImageDataGenerator(rescale=1./255) # 1/255przeskalowanie wartości pikseli do od 0 do 1, normalizacja

datagen_train = datagen.flow_from_directory(
    'C:\\Users\\48694\\Desktop\\yellow_ducks\\jdszr9-yellow_ducks\\DL_projekt\\train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

datagen_test = datagen.flow_from_directory(
    'C:\\Users\\48694\\Desktop\\yellow_ducks\\jdszr9-yellow_ducks\\DL_projekt\\test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

datagen_valid = datagen.flow_from_directory(
    'C:\\Users\\48694\\Desktop\\yellow_ducks\\jdszr9-yellow_ducks\\DL_projekt\\valid',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 84635 images belonging to 525 classes.
# Found 2625 images belonging to 525 classes.
# Found 2625 images belonging to 525 classes.

# %%
# wyświetlanie randomowych zdjęć
# pobieramy pierwszą partię danych z generatora
x_batch, y_batch = datagen_train.next()

# wyświetlamy 9 losowych zdjęć z partii
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(x_batch[i])
    ax.axis('off')
plt.show()
