# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
emissions_capita = pd.read_csv('emissions_capita2.csv')

# %%
pd.set_option('display.max_rows', 500)

# %%
emissions_capita.head()
# Out:
#                               Series Name     Series Code    Country Name  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC     Afghanistan
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC         Albania
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC         Algeria
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  American Samoa
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC         Andorra
#
#   Country Code     1990 [YR1990]      1991 [YR1991]      1992 [YR1992]  \
# 0          AFG   0.2225381391099  0.207535164413917  0.115281586055672
# 1          ALB  1.81954163372931   1.24281022043045  0.683699826210896
# 2          DZA  2.46648708676054   2.54190868146188   2.49885011396798
# 3          ASM                ..                 ..                 ..
# 4          AND  7.65368030017361   7.39618284807158   7.15744636279524
#
#         1993 [YR1993]       1994 [YR1994]       1995 [YR1995]  ...  \
# ...

# %%
emissions_capita.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]'],
#       dtype='object')

# %%
emissions_capita.drop(emissions_capita.index[266:], axis=0, inplace=True)
emissions_capita.drop('Series Code', axis=1, inplace=True)
emissions_capita.drop('Country Code', axis=1, inplace=True)
emissions_capita.drop('Series Name', axis=1, inplace=True)
emissions_capita.drop('2020 [YR2020]', axis=1, inplace=True)
emissions_capita.drop('2021 [YR2021]', axis=1, inplace=True)
emissions_capita2 = emissions_capita.replace('..', np.nan)

emissions_capita = emissions_capita2.astype(
    {'1991 [YR1991]': 'float',
     '1990 [YR1990]': 'float',
     '1992 [YR1992]': 'float',
     '1993 [YR1993]': 'float',
     '1994 [YR1994]': 'float',
     '1995 [YR1995]': 'float',
     '1996 [YR1996]': 'float',
     '1997 [YR1997]': 'float',
     '1998 [YR1998]': 'float',
     '1999 [YR1999]': 'float',
     '2000 [YR2000]': 'float',
     '2001 [YR2001]': 'float',
     '2002 [YR2002]': 'float',
     '2003 [YR2003]': 'float',
     '2004 [YR2004]': 'float',
     '2005 [YR2005]': 'float',
     '2006 [YR2006]': 'float',
     '2007 [YR2007]': 'float',
     '2008 [YR2008]': 'float',
     '2009 [YR2009]': 'float',
     '2010 [YR2010]': 'float',
     '2011 [YR2011]': 'float',
     '2012 [YR2012]': 'float',
     '2013 [YR2013]': 'float',
     '2014 [YR2014]': 'float',
     '2015 [YR2015]': 'float',
     '2016 [YR2016]': 'float',
     '2017 [YR2017]': 'float',
     '2018 [YR2018]': 'float',
     '2019 [YR2019]': 'float'})
emissions_capita.columns = ['Country Name',1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# %%
emissions_capita3 = emissions_capita.copy()
emissions_capita3['dif'] = emissions_capita[1990] - emissions_capita[2019]

# %%
emissions_capita3.sort_values('dif', ascending = False)
# Out:
#                                           Country Name       1990       1991  \
# 62                                             Estonia  22.483166  20.200933
# 116                                         Luxembourg  29.566584  30.361757
# 203                                            Ukraine  13.270407  12.536995
# 137                                              Nauru  13.544488  13.128661
# 204                               United Arab Emirates  29.055586  30.651524
# 129                                            Moldova  10.293401   8.273886
# 52                                             Czechia  14.535453  13.280202
# 53                                             Denmark  10.132390  12.184006
# 206                                      United States  19.407346  19.003403
# 173                                    Slovak Republic  10.343096   9.039665
# 205                                     United Kingdom   9.812990   9.937850
# ...

# %%
emissions_capita3.sort_values(2019, ascending = False)
# Out:
#                                           Country Name       1990       1991  \
# 159                                              Qatar  28.391917  32.815902
# 14                                             Bahrain  20.756912  19.330799
# 106                                             Kuwait  17.391689   5.837999
# 204                               United Arab Emirates  29.055586  30.651524
# 148                                               Oman   6.605620   8.294696
# 28                                   Brunei Darussalam  12.446168  12.525013
# 35                                              Canada  15.148890  14.741014
# 116                                         Luxembourg  29.566584  30.361757
# 10                                           Australia  15.448463  15.318181
# 251                                      North America  18.984350  18.580398
# 206                                      United States  19.407346  19.003403
# ...

# %%
emissions_capita[emissions_capita['Country Name'].str.contains('income')==True]
# Out:
#                                           Country Name       1990       1991  \
# 224        East Asia & Pacific (excluding high income)   1.668698   1.740518
# 228      Europe & Central Asia (excluding high income)  10.628425  10.259978
# 233                                        High income  11.358937  11.261473
# 241  Latin America & Caribbean (excluding high income)   1.849874   1.882314
# 244                                Low & middle income   2.078788   2.073990
# 245                                         Low income   0.628983   0.603745
# 246                                Lower middle income   1.113017   1.120878
# 248  Middle East & North Africa (excluding high inc...   2.353809   2.358295
# 250                                      Middle income   2.190205   2.187778
# 262         Sub-Saharan Africa (excluding high income)   0.778658   0.772803
# 264                                Upper middle income   3.317207   3.313213
#
# ...

# %%
years = list(range(1990,2020))

# %%
emissions_capita[emissions_capita['Country Name']=='Poland']
# Out:
#     Country Name      1990      1991      1992     1993     1994      1995  \
# 156       Poland  9.189263  9.193595  8.950396  8.94455  8.81491  8.809432
#
#          1996      1997     1998  ...      2010      2011      2012      2013  \
# 156  9.199373  8.916767  8.23542  ...  8.247028  8.159838  7.969648  7.841705
#
#          2014      2015      2016      2017      2018      2019
# 156  7.516889  7.610089  7.895689  8.238615  8.213616  7.773642
#
# [1 rows x 31 columns]

# %%
Polska_emisja = emissions_capita[emissions_capita['Country Name']=='Poland'].iloc[:,1:].transpose()
Polska_emisja.columns = ['emissions']

# %%
Niemcy_emisja = emissions_capita[emissions_capita['Country Name']=='Germany'].iloc[:,1:].transpose()
Niemcy_emisja.columns = ['emissions']

# %%
Francja_emisja = emissions_capita[emissions_capita['Country Name']=='France'].iloc[:,1:].transpose()
Francja_emisja.columns = ['emissions']

# %%
Finlandia_emisja = emissions_capita[emissions_capita['Country Name']=='Finland'].iloc[:,1:].transpose()
Finlandia_emisja.columns = ['emissions']

# %%
Dania_emisja = emissions_capita[emissions_capita['Country Name']=='Denmark'].iloc[:,1:].transpose()
Dania_emisja.columns = ['emissions']

# %%
Estonia_emisja = emissions_capita[emissions_capita['Country Name']=='Estonia'].iloc[:,1:].transpose()
Estonia_emisja.columns = ['emissions']

# %%
Chiny_emisja = emissions_capita[emissions_capita['Country Name']=='China'].iloc[:,1:].transpose()
Chiny_emisja.columns = ['emissions']

# %%
fig, ax1 = plt.subplots()
ax1.stackplot(years,Polska_emisja.emissions, Niemcy_emisja.emissions, Francja_emisja.emissions, Finlandia_emisja.emissions, Dania_emisja.emissions, Estonia_emisja.emissions, labels=['Polska', 'Niemcy', 'Francja', 'Finlandia', 'Dania', 'Estonia'])
plt.legend()
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.plot(years, Polska_emisja.emissions, label='Poland')
ax1.plot(years, Niemcy_emisja.emissions, label='Germany')
ax1.plot(years, Francja_emisja.emissions, label='France')
ax1.plot(years, Finlandia_emisja.emissions, label = 'Finland')
ax1.plot(years, Estonia_emisja.emissions, label = 'Estonia')
ax1.plot(years, Dania_emisja.emissions, label = 'Denmark')
ax1.plot(years, Chiny_emisja.emissions, label = 'China')
ax1.set_ylabel('CO2 emissions (metric tons per capita)')
ax1.set_xlabel('Year')
ax1.set_title('EUROPE + CHINA')
plt.legend()
plt.show()

# %%
high_income_emisja = emissions_capita[emissions_capita['Country Name']=='High income'].iloc[:,1:].transpose()
high_income_emisja.columns = ['emissions']

# %%
low_income_emisja = emissions_capita[emissions_capita['Country Name']=='Low income'].iloc[:,1:].transpose()
low_income_emisja.columns = ['emissions']
